# %% [markdown]
# ### Creating an Empty Deposition

# %%
from client import Zenodo
from entities.metadata import metadata, publication_types, upload_types
import json, requests
from datetime import datetime, timezone
import pprint

# %%
cli = Zenodo(use_sandbox=False)
# Out:
# WARNING: The config file (~/.zenodorc) is found.

# %%
import resource


depo = cli.init_deposition()
reco = cli.init_records()
lic = cli.init_resources(resource="communities")

# %%
lic_list = lic.list_resources()
lic_list[0].data
# Out:
# {'updated': '2021-03-02T15:26:56.137812+00:00',
#  'id_user': 1161,
#  'description': '<p>A community to share publications related to bio-systematics. The goal is to provide</p>\r\n\r\n<ol>\r\n\t<li>open access to publications cited in publications or in combination with scientific names</li>\r\n\t<li>open access FAIR data with focus on taxon treatments and figures liberated from publications</li>\r\n\t<li>a digital object identifier (DOI) to enable citation of the publications and data including direct access to its digital representation.</li>\r\n</ol>\r\n\r\n<p>For additional search functionality&nbsp; can be used. This includes also searches in CrossRef, DataCite, PubMed, RefBank, GNUB and Mendeley.</p>\r\n',
#  'links': {'self': 'https://zenodo.org/api/communities/biosyslit',
#   'html': 'https://zenodo.org/communities/biosyslit/'},
#  'created': '2013-11-11T14:14:18+00:00',
#  'title': 'Biodiversity Literature Repository',
#  'id': 'biosyslit',
#  'last_record_accepted': '2017-05-23T13:27:06.990269+00:00',
#  'logo_url': 'https://zenodo.org/api/files/00000000-0000-0000-0000-000000000000/biosyslit/logo.png',
#  'page': '<p><strong>Upload guideline</strong></p>\r\n\r\n<p>A provisional guideline how to upload is <a href="https://drive.google.com/file/d/0B_yrQwn4yBySX3JkTV9RZzZfNUU/view?usp=sharing">here</a>.</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<p>&nbsp;</p>\r\n',
#  'curation_policy': '<ol>\r\n\t<li>If an uploaded document has an existing DOI, it will be kept. If there is no DOI, a Zenodo DOI will be minted for the item.</li>\r\n\t<li>Items with Open Access remain Open Access.</li>\r\n\t<li>Items with closed access remain closed. If they are published on 31.12.1999 or earlier, they are made accessible for reading. Please consult your national copyright law for conditions of reuse.</li>\r\n\t<li>To upload publications, please contact <a href="mailto:info@plazi.org">info@plazi.org</a>.</li>\r\n</ol>\r\n'}

# %%
lic.retrieve_resource(id_="molssi").data
# Out:
# {'updated': '2021-08-02T17:07:55.747006+00:00',
#  'id_user': 68559,
#  'description': '<p>Zenodo community for the MolSSI.</p>\r\n',
#  'links': {'self': 'https://zenodo.org/api/communities/molssi',
#   'html': 'https://zenodo.org/communities/molssi/'},
#  'created': '2021-08-02T17:07:55.608802+00:00',
#  'title': 'Molecular Sciences Software Institute',
#  'id': 'molssi',
#  'last_record_accepted': '2000-01-01T00:00:00+00:00',
#  'logo_url': 'https://zenodo.org/api/files/00000000-0000-0000-0000-000000000000/molssi/logo.png',
#  'page': '',
#  'curation_policy': ''}

# %%
rec = lic.retrieve_license(id_="cc-by-nc-4.0")
rec.data
# Out:
# {'created': '2016-09-12T02:51:35.985727+00:00',
#  'id': 'cc-by-nc-4.0',
#  'links': {'self': 'https://zenodo.org/api/licenses/cc-by-nc-4.0'},
#  'metadata': {'$schema': 'http://zenodo.org/schemas/licenses/license-v1.0.0.json',
#   'domain_content': False,
#   'domain_data': False,
#   'domain_software': False,
#   'family': '',
#   'id': 'CC-BY-NC-4.0',
#   'maintainer': '',
#   'od_conformance': 'not reviewed',
#   'osd_conformance': 'not reviewed',
#   'status': 'active',
#   'title': 'Creative Commons Attribution Non Commercial 4.0 International',
#   'url': 'https://creativecommons.org/licenses/by-nc/4.0/legalcode'},
#  'updated': '2021-10-07T08:21:24.564024+00:00'}

# %%
rec = reco.retrieve_record(id_=rec_list[0].data["id"])
rec.data
# Out:
# {'conceptdoi': '10.5281/zenodo.5153984',
#  'conceptrecid': '5153984',
#  'created': '2022-07-25T14:36:34.117418+00:00',
#  'doi': '10.5281/zenodo.6902118',
#  'files': [{'bucket': 'f78ed59e-06ff-41f0-a86c-0ca46891b5f9',
#    'checksum': 'md5:a5e2e9df15fa9f78c0303b38afbd77f7',
#    'key': 'molssi-seamm/seamm-2022.7.25.zip',
#    'links': {'self': 'https://zenodo.org/api/files/f78ed59e-06ff-41f0-a86c-0ca46891b5f9/molssi-seamm/seamm-2022.7.25.zip'},
#    'size': 278814,
#    'type': 'zip'}],
#  'id': 6902118,
#  'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.6902118.svg',
#   'bucket': 'https://zenodo.org/api/files/f78ed59e-06ff-41f0-a86c-0ca46891b5f9',
#   'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5153984.svg',
#   'conceptdoi': 'https://doi.org/10.5281/zenodo.5153984',
#   'doi': 'https://doi.org/10.5281/zenodo.6902118',
#   'html': 'https://zenodo.org/record/6902118',
#   'latest': 'https://zenodo.org/api/records/6902118',
#   'latest_html': 'https://zenodo.org/record/6902118',
#   'self': 'https://zenodo.org/api/records/6902118'},
#  'metadata': {'access_right': 'open',
#   'access_right_category': 'success',
#   'communities': [{'id': 'molssi'}, {'id': 'seamm'}, {'id': 'seamm-core'}],
#   'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#     'name': 'Nash, Jessica',
#     'orcid': '0000-0003-1967-5094'},
#    {'affiliation': 'Molecular Sciences Software Institute',
#     'name': 'Marin-Rimoldi, Eliseo',
#     'orcid': '0000-0003-1721-4366'},
#    {'affiliation': 'Molecular Sciences Software Institute',
#     'name': 'Saxe, Paul',
#     'orcid': '0000-0002-8641-9448'}],
#   'description': 'The core of the SEAMM environment and graphical interface.',
#   'doi': '10.5281/zenodo.6902118',
#   'keywords': ['computational chemistry', 'computational materials science'],
#   'license': {'id': 'LGPL-3.0-or-later'},
#   'notes': 'Funding: NSF OAC-1547580 and CHE-2136142',
#   'publication_date': '2022-07-25',
#   'related_identifiers': [{'identifier': 'https://github.com/molssi-seamm/seamm/tree/2022.7.25',
#     'relation': 'isSupplementTo',
#     'scheme': 'url'},
#    {'identifier': '10.5281/zenodo.5153984',
#     'relation': 'isVersionOf',
#     'scheme': 'doi'}],
#   'relations': {'version': [{'count': 16,
#      'index': 15,
#      'is_last': True,
#      'last_child': {'pid_type': 'recid', 'pid_value': '6902118'},
#      'parent': {'pid_type': 'recid', 'pid_value': '5153984'}}]},
#   'resource_type': {'title': 'Software', 'type': 'software'},
#   'title': 'SEAMM: Simulation Environment for Atomistic and Molecular Modeling',
#   'version': '2022.7.25'},
#  'owners': [246044],
#  'revision': 3,
#  'stats': {'downloads': 0.0,
#   'unique_downloads': 0.0,
#   'unique_views': 7.0,
#   'version_downloads': 54.0,
#   'version_unique_downloads': 44.0,
#   'version_unique_views': 262.0,
#   'version_views': 317.0,
#   'version_volume': 14663447.0,
#   'views': 7.0,
#   'volume': 0.0},
#  'updated': '2022-07-26T01:49:01.630880+00:00'}

# %%
rec_list[0].data["id"]
# Out:
# 6902118

# %%
rec_list = reco.list_records(communities="molssi")
rec_list
# rec_list[0].data
# Out:
# The value of 'content_type' argument is None.
# ZenoPy will adopt JSON encoding.
#
# The value of 'status' argument is None.
# ZenoPy will search for 'published' record.
#
# The value of 'sort' argument is None.
# ZenoPy will sort the search results according to 'bestmatch' sort option.
# [<entities.record.Record at 0x7f43788c6440>,
#  <entities.record.Record at 0x7f43788c6320>,
#  <entities.record.Record at 0x7f43788c6620>,
#  <entities.record.Record at 0x7f43882f7010>,
#  <entities.record.Record at 0x7f43882f69b0>,
#  <entities.record.Record at 0x7f43882f6950>,
#  <entities.record.Record at 0x7f43882f6aa0>,
#  <entities.record.Record at 0x7f43882f7790>,
#  <entities.record.Record at 0x7f43882f7730>,
#  <entities.record.Record at 0x7f43882f6a10>]

# %%
for idx in range(len(rec_list)):
    print(rec_list[idx].data["metadata"]["title"])
# Out:
# SEAMM: Simulation Environment for Atomistic and Molecular Modeling
# Plug-in for SEAMM for building fluid systems with PACKMOL.
# MolSSI Guidelines on APOD Cyclic Parallelization Strategy
# Plug-in for SEAMM to allow custom python scripts in flowcharts
# DES5M
# DESS66 and DESS66x8
# DES370K
# DES15K
# Plug-in for SEAMM to create structures from SMILES
# MolSSI Formatting Guidelines for Machine Learning Products

# %%
import requests
import json

# %%
url = "https://zenodo.org/api/records"
# url = "https://sandbox.zenodo.org/api/deposit/depositions"
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx"
}
query = json.dumps({ 
    "status": "draft"
    },
)
params = {
    "status": "published",
    # "page": 100,
    "size": 10,
    "sort": "bestmatch",
    "communities": "molssi",
    'access_token': 'f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx'
}
r = requests.get(url=url, params=params, headers=headers)
response = r.json()
response["hits"]["hits"]
# Out:
# [{'conceptdoi': '10.5281/zenodo.5676265',
#   'conceptrecid': '5676265',
#   'created': '2021-11-11T19:54:32.747192+00:00',
#   'doi': '10.5281/zenodo.5676266',
#   'files': [{'bucket': 'cb21c783-77f8-492e-9713-d0cdaa7608d4',
#     'checksum': 'md5:b2b2bf8bc0dd436cfc1ab159d86421fd',
#     'key': 'DES370K.zip',
#     'links': {'self': 'https://zenodo.org/api/files/cb21c783-77f8-492e-9713-d0cdaa7608d4/DES370K.zip'},
#     'size': 262493084,
#     'type': 'zip'}],
#   'id': 5676266,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676266.svg',
#    'bucket': 'https://zenodo.org/api/files/cb21c783-77f8-492e-9713-d0cdaa7608d4',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676265.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5676265',
#    'doi': 'https://doi.org/10.5281/zenodo.5676266',
#    'html': 'https://zenodo.org/record/5676266',
#    'latest': 'https://zenodo.org/api/records/5676266',
#    'latest_html': 'https://zenodo.org/record/5676266',
#    'self': 'https://zenodo.org/api/records/5676266'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}],
#    'creators': [{'affiliation': 'D. E. Shaw Research',
#      'name': 'Donchev, Alexander G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Taube, Andrew G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Decolvenaere, Elizabeth'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Hargus, Cory'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'McGibbon, Robert T'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Law, Ka-Hei'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Gregersen, Brent A'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Li Je-Leun'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Palmo, Kim'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Siva. Karthik'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Bergdorf, Michael'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Klepeis. John L'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Shaw, David E'}],
#    'description': '<p>DESRES Data Sets (DES370K)<br>\n=========================================<br>\nPlease see the original paper at https://doi.org/10.1038/s41597-021-00833-x for<br>\nmore information about this dataset.</p>\n\n<p>This package contains a datasets described by Donchev et al. [1]: DES370K, It<br>\nis presented as a CSV (DES370K.csv) and .mol files<br>\n(geometries/&lt;system_id&gt;/DES370K_&lt;geom_id&gt;.mol). Also included is a metadata<br>\nfile DES370K_meta.csv, which contains a set of long-form column descriptions<br>\nreplicating those in [1], as well as data types and units (when applicable) for<br>\neach column.</p>\n\n<p>Manifest<br>\n--------<br>\n- DES370K.csv &nbsp; &nbsp; &nbsp; : Full dataset, containing interaction energies calculated<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; using CCSD(T), MP2, HF, and SAPT0, as well as dimer<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; geometries.</p>\n\n<p>- DES370K_meta.csv &nbsp;: Long-form descriptions of the columns in DES370K, as well<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; as datatypes and units (when applicable) for each column</p>\n\n<p>- LICENSE.txt &nbsp; &nbsp; &nbsp; : License for using and redistributing the datasets<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; provided.</p>\n\n<p>- README.md &nbsp; &nbsp; &nbsp; &nbsp; : This file.</p>\n\n<p>Loading the Datset<br>\n------------------<br>\nThe datasets are presented as CSVs as a compromise between human-readability,<br>\nformat uniformity, and parsing speed. While an almost uncountable number of<br>\npackages exist to read CSV files, we recommend using the python data analysis</p>\n\n<p>References<br>\n----------<br>\n[1] &nbsp;A. G. Donchev, A. G. Taube, E. Decolvenaere, C. Hargus, R. T. McGibbon,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, B. A. Gregersen, J.-L. Li, K. Palmo, K. Siva, M. Bergdorf,<br>\n&nbsp; &nbsp; &nbsp; J. L. Klepeis, and D. E. Shaw. &quot;Quantum chemical benchmark database of<br>\n&nbsp; &nbsp; &nbsp; dimer interaction energies at a &ldquo;gold standard&rdquo; level of accuracy&quot;</p>\n\n<p>[2] &nbsp;R. T. McGibbon, A. G. Taube, A. G. Donchev, K. Siva, F. Fernandez, C. Hargus,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, J.L. Klepeis, and D. E. Shaw. &quot;Improving the accuracy of<br>\n&nbsp; &nbsp; &nbsp; Moller-Plesset perturbation theory with neural networks&quot;</p>\n\n<p>[3] &nbsp;M. K. Kesharwani, A. Karton, N. Sylvetsky, J. M. L. Nitai. &quot;The S66<br>\n&nbsp; &nbsp; &nbsp; non-covalent interactions benchmark reconsidered using explicitly<br>\n&nbsp; &nbsp; &nbsp; correlated methods near the basis set limit.&quot;</p>\n\n<p>License<br>\n-------<br>\n```<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; DESRES DATA SETS LICENSE AGREEMENT</p>\n\n<p>Copyright 2020, D. E. Shaw Research. All rights reserved.</p>\n\n<p>Redistribution and use of electronic structure data released in the DESRES<br>\nData Sets (DES370K, DES15K, DES5M, DESS66, and DESS66x8) with or without<br>\nmodification, is permitted provided that the following conditions are met:</p>\n\n<p>&nbsp; &nbsp; * Redistributions of the data must retain the above copyright notice,<br>\n&nbsp; &nbsp; this list of conditions, and the following disclaimer.</p>\n\n<p>&nbsp; &nbsp; * Redistributions in binary form must reproduce the above copyright<br>\n&nbsp; &nbsp; notice, this list of conditions, and the following disclaimer in the<br>\n&nbsp; &nbsp; documentation and/or other materials provided with the distribution.</p>\n\n<p>Neither the name of D. E. Shaw Research nor the names of its contributors may<br>\nbe used to endorse or promote products derived from this software without<br>\nspecific prior written permission.</p>\n\n<p>THIS SOFTWARE AND DATA ARE PROVIDED BY THE COPYRIGHT HOLDERS AND CONTRIBUTORS<br>\n&quot;AS IS&quot; AND ANY EXPRESS OR IMPLIED WA ...
#    'doi': '10.5281/zenodo.5676266',
#    'keywords': ['coupled cluster',
#     'non-covalent interactions',
#     'MP2',
#     'CCSD(T)',
#     'dimers'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2021-02-10',
#    'related_identifiers': [{'identifier': '10.1038/s41597-021-00833-x',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.6084/m9.figshare.c.5070644',
#      'relation': 'isNewVersionOf',
#      'resource_type': 'dataset',
#      'scheme': 'doi'},
#     {'identifier': '10.1063/1.4986081',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.5281/zenodo.5676265',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5676266'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5676265'}}]},
#    'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#    'title': 'DES370K',
#    'version': '1.0.0'},
#   'owners': [257713],
#   'revision': 5,
#   'stats': {'downloads': 6.0,
#    'unique_downloads': 5.0,
#    'unique_views': 52.0,
#    'version_downloads': 6.0,
#    'version_unique_downloads': 5.0,
#    'version_unique_views': 52.0,
#    'version_views': 69.0,
#    'version_volume': 1574958504.0,
#    'views': 69.0,
#    'volume': 1574958504.0},
#   'updated': '2021-11-12T17:14:11.987731+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5330689',
#   'conceptrecid': '5330689',
#   'created': '2022-05-31T19:34:51.817157+00:00',
#   'doi': '10.5281/zenodo.6600344',
#   'files': [{'bucket': '146fc818-ed8f-45e9-91ad-adf33d296f48',
#     'checksum': 'md5:09b315f80e1f2547bf2c88e55fe0d42d',
#     'key': 'molssi-seamm/packmol_step-2022.5.31.zip',
#     'links': {'self': 'https://zenodo.org/api/files/146fc818-ed8f-45e9-91ad-adf33d296f48/molssi-seamm/packmol_step-2022.5.31.zip'},
#     'size': 129998,
#     'type': 'zip'}],
#   'id': 6600344,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.6600344.svg',
#    'bucket': 'https://zenodo.org/api/files/146fc818-ed8f-45e9-91ad-adf33d296f48',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5330689.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5330689',
#    'doi': 'https://doi.org/10.5281/zenodo.6600344',
#    'html': 'https://zenodo.org/record/6600344',
#    'latest': 'https://zenodo.org/api/records/6600344',
#    'latest_html': 'https://zenodo.org/record/6600344',
#    'self': 'https://zenodo.org/api/records/6600344'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'},
#     {'id': 'seamm'},
#     {'id': 'seamm-plug-ins'}],
#    'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': '<p>Provides a step in a flowchart for packing reasonably small molecules into a periodic cell using PACKMOL. This is used for preparing models of liquids and gases with one or more components given the stoichiometry. The size if the resulting model is specified by giving two independent parameters such as the density and number of molecule, or volume and total number of atoms. In addition, using the ideal gas model you can specify the temperature, pressure and either the volume, length of the cell side, or total number of molecules or atoms to create the model</p>',
#    'doi': '10.5281/zenodo.6600344',
#    'keywords': ['computational chemistry', 'computational materials science'],
#    'license': {'id': 'BSD-3-Clause'},
#    'notes': 'Funding including NSF OAC-1547580 and CHE-2136142 grants',
#    'publication_date': '2022-05-31',
#    'related_identifiers': [{'identifier': 'https://github.com/molssi-seamm/packmol_step/tree/2022.5.31',
#      'relation': 'isSupplementTo',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.5330689',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 4,
#       'index': 3,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '6600344'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5330689'}}]},
#    'resource_type': {'title': 'Software', 'type': 'software'},
#    'title': 'Plug-in for SEAMM for building fluid systems with PACKMOL.',
#    'version': '2022.5.31'},
#   'owners': [246044],
#   'revision': 3,
#   'stats': {'downloads': 0.0,
#    'unique_downloads': 0.0,
#    'unique_views': 6.0,
#    'version_downloads': 21.0,
#    'version_unique_downloads': 20.0,
#    'version_unique_views': 86.0,
#    'version_views': 92.0,
#    'version_volume': 1828253.0,
#    'views': 6.0,
#    'volume': 0.0},
#   'updated': '2022-06-01T01:51:33.873975+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5309099',
#   'conceptrecid': '5309099',
#   'created': '2021-11-27T22:09:33.273752+00:00',
#   'doi': '10.5281/zenodo.5732452',
#   'files': [{'bucket': 'bf2b4061-164e-48e1-8aea-ea5f661ee29d',
#     'checksum': 'md5:8de9eb63e8d24a61910953acdf972012',
#     'key': 'molssi-seamm/custom_step-2021.11.27.zip',
#     'links': {'self': 'https://zenodo.org/api/files/bf2b4061-164e-48e1-8aea-ea5f661ee29d/molssi-seamm/custom_step-2021.11.27.zip'},
#     'size': 85404,
#     'type': 'zip'}],
#   'id': 5732452,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5732452.svg',
#    'bucket': 'https://zenodo.org/api/files/bf2b4061-164e-48e1-8aea-ea5f661ee29d',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5309099.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5309099',
#    'doi': 'https://doi.org/10.5281/zenodo.5732452',
#    'html': 'https://zenodo.org/record/5732452',
#    'latest': 'https://zenodo.org/api/records/5732452',
#    'latest_html': 'https://zenodo.org/record/5732452',
#    'self': 'https://zenodo.org/api/records/5732452'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'},
#     {'id': 'seamm'},
#     {'id': 'seamm-plug-ins'}],
#    'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': '<p>Provides a step in a flowchart for the user to add a Python script which will run in the current environment, giving access to the internal variables of SEAMM as well as the structures.</p>',
#    'doi': '10.5281/zenodo.5732452',
#    'keywords': ['computational chemistry', 'computational materials science'],
#    'license': {'id': 'BSD-3-Clause'},
#    'notes': 'Funding including NSF OAC-1547580 and CHE-2136142 grants',
#    'publication_date': '2021-11-27',
#    'related_identifiers': [{'identifier': 'https://github.com/molssi-seamm/custom_step/tree/2021.11.27',
#      'relation': 'isSupplementTo',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.5309099',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 3,
#       'index': 2,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5732452'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5309099'}}]},
#    'resource_type': {'title': 'Software', 'type': 'software'},
#    'title': 'Plug-in for SEAMM to allow custom python scripts in flowcharts',
#    'version': '2021.11.27'},
#   'owners': [246044],
#   'revision': 3,
#   'stats': {'downloads': 3.0,
#    'unique_downloads': 3.0,
#    'unique_views': 30.0,
#    'version_downloads': 27.0,
#    'version_unique_downloads': 22.0,
#    'version_unique_views': 50.0,
#    'version_views': 56.0,
#    'version_volume': 2303020.0,
#    'views': 32.0,
#    'volume': 256212.0},
#   'updated': '2021-11-28T01:48:44.254201+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5159800',
#   'conceptrecid': '5159800',
#   'created': '2021-10-14T00:55:44.225529+00:00',
#   'doi': '10.5281/zenodo.5567880',
#   'files': [{'bucket': 'a102cdf6-6654-4fc0-b62c-dfef70f3293f',
#     'checksum': 'md5:61f4e5ad5125455337c36bbeaf807bc9',
#     'key': 'molssi-seamm/from_smiles_step-2021.10.13.zip',
#     'links': {'self': 'https://zenodo.org/api/files/a102cdf6-6654-4fc0-b62c-dfef70f3293f/molssi-seamm/from_smiles_step-2021.10.13.zip'},
#     'size': 71520,
#     'type': 'zip'}],
#   'id': 5567880,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5567880.svg',
#    'bucket': 'https://zenodo.org/api/files/a102cdf6-6654-4fc0-b62c-dfef70f3293f',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5159800.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5159800',
#    'doi': 'https://doi.org/10.5281/zenodo.5567880',
#    'html': 'https://zenodo.org/record/5567880',
#    'latest': 'https://zenodo.org/api/records/5567880',
#    'latest_html': 'https://zenodo.org/record/5567880',
#    'self': 'https://zenodo.org/api/records/5567880'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'},
#     {'id': 'seamm'},
#     {'id': 'seamm-plug-ins'}],
#    'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': '<p>Provides a step in a flowchart for converting a specification of a molecule using SMILES into a 3-D structure suitable as input for for simulations.</p>',
#    'doi': '10.5281/zenodo.5567880',
#    'keywords': ['computational chemistry', 'computational materials science'],
#    'license': {'id': 'BSD-3-Clause'},
#    'notes': 'Funding including NSF OAC-1547580 and CHE-2136142 grants',
#    'publication_date': '2021-10-14',
#    'related_identifiers': [{'identifier': 'https://github.com/molssi-seamm/from_smiles_step/tree/2021.10.13',
#      'relation': 'isSupplementTo',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.5159800',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 4,
#       'index': 3,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5567880'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5159800'}}]},
#    'resource_type': {'title': 'Software', 'type': 'software'},
#    'title': 'Plug-in for SEAMM to create structures from SMILES',
#    'version': '2021.10.13'},
#   'owners': [246044],
#   'revision': 3,
#   'stats': {'downloads': 8.0,
#    'unique_downloads': 8.0,
#    'unique_views': 10.0,
#    'version_downloads': 25.0,
#    'version_unique_downloads': 20.0,
#    'version_unique_views': 37.0,
#    'version_views': 54.0,
#    'version_volume': 1787274.0,
#    'views': 13.0,
#    'volume': 572160.0},
#   'updated': '2021-10-14T01:48:42.163053+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5389981',
#   'conceptrecid': '5389981',
#   'created': '2021-09-02T16:41:11.277319+00:00',
#   'doi': '10.5281/zenodo.5389982',
#   'files': [{'bucket': '6b6e5721-930a-46bf-80ad-15a1ff35e23b',
#     'checksum': 'md5:32daf9cba263bbce5c4f744bd62f2558',
#     'key': 'ML_Formatting_Guidelines.odt',
#     'links': {'self': 'https://zenodo.org/api/files/6b6e5721-930a-46bf-80ad-15a1ff35e23b/ML_Formatting_Guidelines.odt'},
#     'size': 21001,
#     'type': 'odt'},
#    {'bucket': '6b6e5721-930a-46bf-80ad-15a1ff35e23b',
#     'checksum': 'md5:185ea215c01d4f44a2c398cbe8856214',
#     'key': 'ML_Formatting_Guidelines.pdf',
#     'links': {'self': 'https://zenodo.org/api/files/6b6e5721-930a-46bf-80ad-15a1ff35e23b/ML_Formatting_Guidelines.pdf'},
#     'size': 92394,
#     'type': 'pdf'}],
#   'id': 5389982,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5389982.svg',
#    'bucket': 'https://zenodo.org/api/files/6b6e5721-930a-46bf-80ad-15a1ff35e23b',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5389981.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5389981',
#    'doi': 'https://doi.org/10.5281/zenodo.5389982',
#    'html': 'https://zenodo.org/record/5389982',
#    'latest': 'https://zenodo.org/api/records/5389982',
#    'latest_html': 'https://zenodo.org/record/5389982',
#    'self': 'https://zenodo.org/api/records/5389982'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'},
#     {'id': 'molssi-guidelines'},
#     {'id': 'seamm-guidelines'}],
#    'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Mostafanejad, Mohammad',
#      'orcid': '0000-0001-9762-7616'},
#     {'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': '<p>This document is a part of <a href="https://molssi.github.io/molssi-guidelines">MolSSI guidelines and best practices</a> which focuses on formatting machine learning products (<em>e.g.</em>, datasets, modules, models, <em>etc.</em>) before submitting them on the <a href="https://zenodo.org/">Zenodo</a> platform and tagging them to one or more curated MolSSI community collections.</p>',
#    'doi': '10.5281/zenodo.5389982',
#    'keywords': ['machine learning',
#     'formatting guidelines',
#     'MolSSI best practices',
#     'MolSSI guidelines'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'notes': 'This work has been funded by the NSF OAC-1547580 and CHE-2136142 grants.',
#    'publication_date': '2021-09-02',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.5389981',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5389982'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5389981'}}]},
#    'resource_type': {'subtype': 'technicalnote',
#     'title': 'Technical note',
#     'type': 'publication'},
#    'title': 'MolSSI Formatting Guidelines for Machine Learning Products',
#    'version': '2021.9.2'},
#   'owners': [68559],
#   'revision': 5,
#   'stats': {'downloads': 60.0,
#    'unique_downloads': 49.0,
#    'unique_views': 69.0,
#    'version_downloads': 60.0,
#    'version_unique_downloads': 49.0,
#    'version_unique_views': 69.0,
#    'version_views': 87.0,
#    'version_volume': 5472247.0,
#    'views': 87.0,
#    'volume': 5472247.0},
#   'updated': '2022-01-20T22:14:12.141358+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5706001',
#   'conceptrecid': '5706001',
#   'created': '2021-11-16T18:22:07.847558+00:00',
#   'doi': '10.5281/zenodo.5706002',
#   'files': [{'bucket': '58116936-8b26-47fa-b9b5-8b3960779662',
#     'checksum': 'md5:50d11239119f787c8137a78973c932e6',
#     'key': 'DESS5M.zip',
#     'links': {'self': 'https://zenodo.org/api/files/58116936-8b26-47fa-b9b5-8b3960779662/DESS5M.zip'},
#     'size': 3825454761,
#     'type': 'zip'}],
#   'id': 5706002,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5706002.svg',
#    'bucket': 'https://zenodo.org/api/files/58116936-8b26-47fa-b9b5-8b3960779662',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5706001.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5706001',
#    'doi': 'https://doi.org/10.5281/zenodo.5706002',
#    'html': 'https://zenodo.org/record/5706002',
#    'latest': 'https://zenodo.org/api/records/5706002',
#    'latest_html': 'https://zenodo.org/record/5706002',
#    'self': 'https://zenodo.org/api/records/5706002'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}],
#    'creators': [{'affiliation': 'D. E. Shaw Research',
#      'name': 'Donchev, Alexander G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Taube, Andrew G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Decolvenaere, Elizabeth'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Hargus, Cory'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'McGibbon, Robert T'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Law, Ka-Hei'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Gregersen, Brent A'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Li Je-Leun'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Palmo, Kim'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Siva. Karthik'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Bergdorf, Michael'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Klepeis. John L'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Shaw, David E'}],
#    'description': '<p>DESRES Data Sets (DES5M)<br>\n=========================================<br>\nPlease see the original paper at https://doi.org/10.1038/s41597-021-00833-x for<br>\nmore information about this dataset.</p>\n\n<p>This package contains a datasets described by Donchev et al. [1]: DES5M, It<br>\nis presented as a CSV (DES5M.csv) and .mol files<br>\n(geometries/&lt;system_id&gt;/DES5M_&lt;geom_id&gt;.mol). Also included is a metadata<br>\nfile DES5M_meta.csv, which contains a set of long-form column descriptions<br>\nreplicating those in [1], as well as data types and units (when applicable) for<br>\neach column.</p>\n\n<p>Manifest<br>\n--------<br>\n- DES5M.csv &nbsp; &nbsp; &nbsp; : Extended dataset, containing interaction energies<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; calculated using SNS-MP2[2], MP2, HF, and SAPT0, as well as<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; dimer geometries.</p>\n\n<p>- DES5M_meta.csv &nbsp;: Long-form descriptions of the columns in DES5M, as well<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; as datatypes and units (when applicable) for each column</p>\n\n<p>- LICENSE.txt &nbsp; &nbsp; : License for using and redistributing the datasets<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; provided.</p>\n\n<p>- README.md &nbsp; &nbsp; &nbsp; : This file.</p>\n\n<p>Loading the Datset<br>\n------------------<br>\nThe datasets are presented as CSVs as a compromise between human-readability,<br>\nformat uniformity, and parsing speed. While an almost uncountable number of<br>\npackages exist to read CSV files, we recommend using the python data analysis</p>\n\n<p>References<br>\n----------<br>\n[1] &nbsp;A. G. Donchev, A. G. Taube, E. Decolvenaere, C. Hargus, R. T. McGibbon,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, B. A. Gregersen, J.-L. Li, K. Palmo, K. Siva, M. Bergdorf,<br>\n&nbsp; &nbsp; &nbsp; J. L. Klepeis, and D. E. Shaw. &quot;Quantum chemical benchmark database of<br>\n&nbsp; &nbsp; &nbsp; dimer interaction energies at a &ldquo;gold standard&rdquo; level of accuracy&quot;</p>\n\n<p>[2] &nbsp;R. T. McGibbon, A. G. Taube, A. G. Donchev, K. Siva, F. Fernandez, C. Hargus,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, J.L. Klepeis, and D. E. Shaw. &quot;Improving the accuracy of<br>\n&nbsp; &nbsp; &nbsp; Moller-Plesset perturbation theory with neural networks&quot;</p>\n\n<p>[3] &nbsp;M. K. Kesharwani, A. Karton, N. Sylvetsky, J. M. L. Nitai. &quot;The S66<br>\n&nbsp; &nbsp; &nbsp; non-covalent interactions benchmark reconsidered using explicitly<br>\n&nbsp; &nbsp; &nbsp; correlated methods near the basis set limit.&quot;</p>\n\n<p>License<br>\n-------<br>\n```<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; DESRES DATA SETS LICENSE AGREEMENT</p>\n\n<p>Copyright 2020, D. E. Shaw Research. All rights reserved.</p>\n\n<p>Redistribution and use of electronic structure data released in the DESRES<br>\nData Sets (DES370K, DES15K, DES5M, DESS66, and DESS66x8) with or without<br>\nmodification, is permitted provided that the following conditions are met:</p>\n\n<p>&nbsp; &nbsp; * Redistributions of the data must retain the above copyright notice,<br>\n&nbsp; &nbsp; this list of conditions, and the following disclaimer.</p>\n\n<p>&nbsp; &nbsp; * Redistributions in binary form must reproduce the above copyright<br>\n&nbsp; &nbsp; notice, this list of conditions, and the following disclaimer in the<br>\n&nbsp; &nbsp; documentation and/or other materials provided with the distribution.</p>\n\n<p>Neither the name of D. E. Shaw Research nor the names of its contributors may<br>\nbe used to endorse or promote products derived from this software without<br>\nspecific prior written permission.</p>\n\n<p>THIS SOFTWARE AND DATA ARE PROVIDED BY THE COPYRIGHT HOLDERS AND CONTRIBUTORS<br>\n&quot;AS IS&quot; AND ANY EXPRESS OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO,<br> ...
#    'doi': '10.5281/zenodo.5706002',
#    'keywords': ['coupled cluster',
#     'non-covalent interactions',
#     'MP2',
#     'CCSD(T)',
#     'dimers',
#     'SNS-MP2'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2021-02-10',
#    'related_identifiers': [{'identifier': '10.1038/s41597-021-00833-x',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.6084/m9.figshare.c.5070644',
#      'relation': 'isNewVersionOf',
#      'resource_type': 'dataset',
#      'scheme': 'doi'},
#     {'identifier': '10.1063/1.4986081',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.5281/zenodo.5706001',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5706002'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5706001'}}]},
#    'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#    'title': 'DES5M',
#    'version': '1.0.0'},
#   'owners': [257713],
#   'revision': 3,
#   'stats': {'downloads': 1.0,
#    'unique_downloads': 1.0,
#    'unique_views': 37.0,
#    'version_downloads': 1.0,
#    'version_unique_downloads': 1.0,
#    'version_unique_views': 37.0,
#    'version_views': 40.0,
#    'version_volume': 3825454761.0,
#    'views': 40.0,
#    'volume': 3825454761.0},
#   'updated': '2021-11-17T01:48:45.697587+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5676283',
#   'conceptrecid': '5676283',
#   'created': '2021-11-11T20:21:15.765507+00:00',
#   'doi': '10.5281/zenodo.5676284',
#   'files': [{'bucket': '77f4e522-75f4-48b5-ae92-a9b31d4a0602',
#     'checksum': 'md5:9df3c70f54f7f52856ee4d53a0b532f5',
#     'key': 'DESS66x8.zip',
#     'links': {'self': 'https://zenodo.org/api/files/77f4e522-75f4-48b5-ae92-a9b31d4a0602/DESS66x8.zip'},
#     'size': 482771,
#     'type': 'zip'},
#    {'bucket': '77f4e522-75f4-48b5-ae92-a9b31d4a0602',
#     'checksum': 'md5:48930e4d01b0844b2c0c1fd2db7cc16b',
#     'key': 'DESS66.zip',
#     'links': {'self': 'https://zenodo.org/api/files/77f4e522-75f4-48b5-ae92-a9b31d4a0602/DESS66.zip'},
#     'size': 80074,
#     'type': 'zip'}],
#   'id': 5676284,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676284.svg',
#    'bucket': 'https://zenodo.org/api/files/77f4e522-75f4-48b5-ae92-a9b31d4a0602',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676283.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5676283',
#    'doi': 'https://doi.org/10.5281/zenodo.5676284',
#    'html': 'https://zenodo.org/record/5676284',
#    'latest': 'https://zenodo.org/api/records/5676284',
#    'latest_html': 'https://zenodo.org/record/5676284',
#    'self': 'https://zenodo.org/api/records/5676284'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}],
#    'creators': [{'affiliation': 'D. E. Shaw Research',
#      'name': 'Donchev, Alexander G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Taube, Andrew G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Decolvenaere, Elizabeth'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Hargus, Cory'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'McGibbon, Robert'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Law, Ka-Hei'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Gregersen, Brent A'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Li, Je-Leun'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Palmo, Kim'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Siva, Karthik'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Bergdorf, Michael'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Klepeis, John L'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Shaw, David E'}],
#    'description': '<p>DESRES Data Sets (DESS66 and S66x8)<br>\n=========================================<br>\nPlease see the original paper at https://doi.org/10.1038/s41597-021-00833-x for<br>\nmore information about this dataset.</p>\n\n<p>This package contains two&nbsp;datasets described by Donchev et al. [1]: DESS66 and DESS66x8, they are&nbsp;presented as CSVs (.../DESS66.csv and .../DESS66x8.csv) and .mol files<br>\n(.../geometries/&lt;system_id&gt;/DESS66[x8]_&lt;geom_id&gt;.mol). Also included is for each is a metadata<br>\nfile DESS66[x8]_meta.csv, which contains a set of long-form column descriptions<br>\nreplicating those in [1], as well as data types and units (when applicable) for<br>\neach column.</p>\n\n<p>Manifest<br>\n--------<br>\n- DESS66.csv &nbsp; &nbsp; &nbsp; : S66 geometries computed in the same style as DES370K,<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;containing interaction energies calculated using CCSD(T),<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;MP2, HF, and SAPT0, as well as dimer geometries, and<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;silver-standard [3] reference values.</p>\n\n<p>- DESS66_meta.csv &nbsp;: Long-form descriptions of the columns in DESS66, as well<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;as datatypes and units (when applicable) for each column<br>\n<br>\n- DESS66x8.csv &nbsp; &nbsp; &nbsp; : S66x8 geometries computed in the same style as DES370K,<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;containing interaction energies calculated using<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;CCSD(T), MP2, HF, and SAPT0, as well as dimer<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;geometries, and bronze-standard [3] reference values.</p>\n\n<p>- DESS66x8_meta.csv &nbsp;: Long-form descriptions of the columns in DESS66x8, as<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;well as datatypes and units (when applicable) for each<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;column</p>\n\n<p>- LICENSE.txt &nbsp; &nbsp; &nbsp;: License for using and redistributing the datasets<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;provided.</p>\n\n<p>- README.md &nbsp; &nbsp; &nbsp; &nbsp;: This file.</p>\n\n<p>Loading the Datset<br>\n------------------<br>\nThe datasets are presented as CSVs as a compromise between human-readability,<br>\nformat uniformity, and parsing speed. While an almost uncountable number of<br>\npackages exist to read CSV files, we recommend using the python data analysis</p>\n\n<p>References<br>\n----------<br>\n[1] &nbsp;A. G. Donchev, A. G. Taube, E. Decolvenaere, C. Hargus, R. T. McGibbon,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, B. A. Gregersen, J.-L. Li, K. Palmo, K. Siva, M. Bergdorf,<br>\n&nbsp; &nbsp; &nbsp; J. L. Klepeis, and D. E. Shaw. &quot;Quantum chemical benchmark database of<br>\n&nbsp; &nbsp; &nbsp; dimer interaction energies at a &ldquo;gold standard&rdquo; level of accuracy&quot;</p>\n\n<p>[2] &nbsp;R. T. McGibbon, A. G. Taube, A. G. Donchev, K. Siva, F. Fernandez, C. Hargus,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, J.L. Klepeis, and D. E. Shaw. &quot;Improving the accuracy of<br>\n&nbsp; &nbsp; &nbsp; Moller-Plesset perturbation theory with neural networks&quot;</p>\n\n<p>[3] &nbsp;M. K. Kesharwani, A. Karton, N. Sylvetsky, J. M. L. Nitai. &quot;The S66<br>\n&nbsp; &nbsp; &nbsp; non-covalent interactions benchmark reconsidered using explicitly<br>\n&nbsp; &nbsp; &nbsp; correlated methods near the basis set limit.&quot;</p>\n\n<p>License<br>\n-------<br>\n```<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; DESRES DATA SETS LICENSE AGREEMENT</p>\n\n<p>Copyri ...
#    'doi': '10.5281/zenodo.5676284',
#    'keywords': ['coupled cluster',
#     'non-covalent interactions',
#     'MP2',
#     'CCSD(T)',
#     'dimers',
#     'S66',
#     'S66x8'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2021-02-10',
#    'related_identifiers': [{'identifier': '10.1038/s41597-021-00833-x',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.1071/CH17588',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.6084/m9.figshare.c.5070644',
#      'relation': 'isNewVersionOf',
#      'resource_type': 'dataset',
#      'scheme': 'doi'},
#     {'identifier': '10.5281/zenodo.5676283',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5676284'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5676283'}}]},
#    'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#    'title': 'DESS66 and DESS66x8',
#    'version': '1.0.0'},
#   'owners': [257713],
#   'revision': 4,
#   'stats': {'downloads': 14.0,
#    'unique_downloads': 7.0,
#    'unique_views': 31.0,
#    'version_downloads': 14.0,
#    'version_unique_downloads': 7.0,
#    'version_unique_views': 31.0,
#    'version_views': 40.0,
#    'version_volume': 5148006.0,
#    'views': 40.0,
#    'volume': 5148006.0},
#   'updated': '2021-11-12T14:34:12.814563+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5676219',
#   'conceptrecid': '5676219',
#   'created': '2021-11-11T18:47:53.783163+00:00',
#   'doi': '10.5281/zenodo.5676220',
#   'files': [{'bucket': 'c739a712-b45b-45eb-8aa5-461f870d5f40',
#     'checksum': 'md5:a64a4c279c376ecfea242c49aea37c87',
#     'key': 'DES15K.zip',
#     'links': {'self': 'https://zenodo.org/api/files/c739a712-b45b-45eb-8aa5-461f870d5f40/DES15K.zip'},
#     'size': 13021309,
#     'type': 'zip'}],
#   'id': 5676220,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676220.svg',
#    'bucket': 'https://zenodo.org/api/files/c739a712-b45b-45eb-8aa5-461f870d5f40',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5676219.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5676219',
#    'doi': 'https://doi.org/10.5281/zenodo.5676220',
#    'html': 'https://zenodo.org/record/5676220',
#    'latest': 'https://zenodo.org/api/records/5676220',
#    'latest_html': 'https://zenodo.org/record/5676220',
#    'self': 'https://zenodo.org/api/records/5676220'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}],
#    'creators': [{'affiliation': 'D. E. Shaw Research',
#      'name': 'Donchev, Alexander G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Taube, Andrew G'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Decolvenaere, Elizabeth'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Hargus, Cory'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'McGibbon, Robert T.'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Law, Ka-Hei'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Gregersen, Brent A'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Li, Je-Leun'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Palmo, Kim'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Siva, Karthik'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Bergdorf, Michael'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Klepeis, John L'},
#     {'affiliation': 'D. E. Shaw Research', 'name': 'Shaw, David E'}],
#    'description': '<p>DESRES Data Sets (DES15K)<br>\n=========================================<br>\nPlease see the original paper at https://doi.org/10.1038/s41597-021-00833-x for<br>\nmore information about this dataset.</p>\n\n<p>This package contains a datasets described by Donchev et al. [1]: DES15K, It<br>\nis presented as a CSV (DES15K.csv) and .mol files<br>\n(geometries/&lt;system_id&gt;/DES15K_&lt;geom_id&gt;.mol). Also included is a metadata<br>\nfile DES15K_meta.csv, which contains a set of long-form column descriptions<br>\nreplicating those in [1], as well as data types and units (when applicable) for<br>\neach column.</p>\n\n<p>Manifest<br>\n--------<br>\n- DES15K.csv &nbsp; &nbsp; &nbsp; : Core dataset, containing interaction energies calculated<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;using CCSD(T), MP2, HF, and SAPT0, as well as dimer<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;geometries.</p>\n\n<p>- DES15K_meta.csv &nbsp;: Long-form descriptions of the columns in DES15K, as well<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;as datatypes and units (when applicable) for each column</p>\n\n<p>- LICENSE.txt &nbsp; &nbsp; &nbsp;: License for using and redistributing the datasets<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;provided.</p>\n\n<p>- README.md &nbsp; &nbsp; &nbsp; &nbsp;: This file.</p>\n\n<p>Loading the Datset<br>\n------------------<br>\nThe datasets are presented as CSVs as a compromise between human-readability,<br>\nformat uniformity, and parsing speed. While an almost uncountable number of<br>\npackages exist to read CSV files, we recommend using the python data analysis</p>\n\n<p>References<br>\n----------<br>\n[1] &nbsp;A. G. Donchev, A. G. Taube, E. Decolvenaere, C. Hargus, R. T. McGibbon,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, B. A. Gregersen, J.-L. Li, K. Palmo, K. Siva, M. Bergdorf,<br>\n&nbsp; &nbsp; &nbsp; J. L. Klepeis, and D. E. Shaw. &quot;Quantum chemical benchmark database of<br>\n&nbsp; &nbsp; &nbsp; dimer interaction energies at a &ldquo;gold standard&rdquo; level of accuracy&quot;</p>\n\n<p>[2] &nbsp;R. T. McGibbon, A. G. Taube, A. G. Donchev, K. Siva, F. Fernandez, C. Hargus,<br>\n&nbsp; &nbsp; &nbsp; K.-H. Law, J.L. Klepeis, and D. E. Shaw. &quot;Improving the accuracy of<br>\n&nbsp; &nbsp; &nbsp; Moller-Plesset perturbation theory with neural networks&quot;</p>\n\n<p>[3] &nbsp;M. K. Kesharwani, A. Karton, N. Sylvetsky, J. M. L. Nitai. &quot;The S66<br>\n&nbsp; &nbsp; &nbsp; non-covalent interactions benchmark reconsidered using explicitly<br>\n&nbsp; &nbsp; &nbsp; correlated methods near the basis set limit.&quot;</p>\n\n<p>License<br>\n-------<br>\n```<br>\n&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; DESRES DATA SETS LICENSE AGREEMENT</p>\n\n<p>Copyright 2020, D. E. Shaw Research. All rights reserved.</p>\n\n<p>Redistribution and use of electronic structure data released in the DESRES<br>\nData Sets (DES370K, DES15K, DES5M, DESS66, and DESS66x8) with or without<br>\nmodification, is permitted provided that the following conditions are met:</p>\n\n<p>&nbsp; &nbsp; * Redistributions of the data must retain the above copyright notice,<br>\n&nbsp; &nbsp; this list of conditions, and the following disclaimer.</p>\n\n<p>&nbsp; &nbsp; * Redistributions in binary form must reproduce the above copyright<br>\n&nbsp; &nbsp; notice, this list of conditions, and the following disclaimer in the<br>\n&nbsp; &nbsp; documentation and/or other materials provided with the distribution.</p>\n\n<p>Neither the name of D. E. Shaw Research nor the names of its contributors may<br>\nbe used to endorse or promote products derived from this software without<br>\nspecific prior written permission.</p>\n\n<p>THIS SOFTWARE AND DATA ARE PROVIDED BY THE COPYRIGHT HOLDERS AND CONTRIBUTORS<br>\n&quot;AS IS&quot; AND ANY EXPRESS OR IMPLIED WARRANTIES, INCL ...
#    'doi': '10.5281/zenodo.5676220',
#    'keywords': ['coupled cluster',
#     'non-covalent interactions',
#     'MP2',
#     'CCSD(T)',
#     'dimers'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'publication_date': '2021-02-10',
#    'related_identifiers': [{'identifier': '10.1038/s41597-021-00833-x',
#      'relation': 'cites',
#      'resource_type': 'publication-article',
#      'scheme': 'doi'},
#     {'identifier': '10.6084/m9.figshare.c.5070644.v1',
#      'relation': 'isNewVersionOf',
#      'resource_type': 'dataset',
#      'scheme': 'doi'},
#     {'identifier': '10.5281/zenodo.5676219',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5676220'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5676219'}}]},
#    'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#    'title': 'DES15K',
#    'version': '1.0.0'},
#   'owners': [257713],
#   'revision': 4,
#   'stats': {'downloads': 7.0,
#    'unique_downloads': 6.0,
#    'unique_views': 32.0,
#    'version_downloads': 7.0,
#    'version_unique_downloads': 6.0,
#    'version_unique_views': 32.0,
#    'version_views': 46.0,
#    'version_volume': 91149163.0,
#    'views': 46.0,
#    'volume': 91149163.0},
#   'updated': '2021-11-12T01:48:41.688546+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5153984',
#   'conceptrecid': '5153984',
#   'created': '2022-07-25T14:36:34.117418+00:00',
#   'doi': '10.5281/zenodo.6902118',
#   'files': [{'bucket': 'f78ed59e-06ff-41f0-a86c-0ca46891b5f9',
#     'checksum': 'md5:a5e2e9df15fa9f78c0303b38afbd77f7',
#     'key': 'molssi-seamm/seamm-2022.7.25.zip',
#     'links': {'self': 'https://zenodo.org/api/files/f78ed59e-06ff-41f0-a86c-0ca46891b5f9/molssi-seamm/seamm-2022.7.25.zip'},
#     'size': 278814,
#     'type': 'zip'}],
#   'id': 6902118,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.6902118.svg',
#    'bucket': 'https://zenodo.org/api/files/f78ed59e-06ff-41f0-a86c-0ca46891b5f9',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5153984.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5153984',
#    'doi': 'https://doi.org/10.5281/zenodo.6902118',
#    'html': 'https://zenodo.org/record/6902118',
#    'latest': 'https://zenodo.org/api/records/6902118',
#    'latest_html': 'https://zenodo.org/record/6902118',
#    'self': 'https://zenodo.org/api/records/6902118'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}, {'id': 'seamm'}, {'id': 'seamm-core'}],
#    'creators': [{'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Nash, Jessica',
#      'orcid': '0000-0003-1967-5094'},
#     {'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Marin-Rimoldi, Eliseo',
#      'orcid': '0000-0003-1721-4366'},
#     {'affiliation': 'Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': 'The core of the SEAMM environment and graphical interface.',
#    'doi': '10.5281/zenodo.6902118',
#    'keywords': ['computational chemistry', 'computational materials science'],
#    'license': {'id': 'LGPL-3.0-or-later'},
#    'notes': 'Funding: NSF OAC-1547580 and CHE-2136142',
#    'publication_date': '2022-07-25',
#    'related_identifiers': [{'identifier': 'https://github.com/molssi-seamm/seamm/tree/2022.7.25',
#      'relation': 'isSupplementTo',
#      'scheme': 'url'},
#     {'identifier': '10.5281/zenodo.5153984',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 16,
#       'index': 15,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '6902118'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5153984'}}]},
#    'resource_type': {'title': 'Software', 'type': 'software'},
#    'title': 'SEAMM: Simulation Environment for Atomistic and Molecular Modeling',
#    'version': '2022.7.25'},
#   'owners': [246044],
#   'revision': 3,
#   'stats': {'downloads': 0.0,
#    'unique_downloads': 0.0,
#    'unique_views': 7.0,
#    'version_downloads': 54.0,
#    'version_unique_downloads': 44.0,
#    'version_unique_views': 238.0,
#    'version_views': 293.0,
#    'version_volume': 14663447.0,
#    'views': 7.0,
#    'volume': 0.0},
#   'updated': '2022-07-26T01:49:01.630880+00:00'},
#  {'conceptdoi': '10.5281/zenodo.5866421',
#   'conceptrecid': '5866421',
#   'created': '2022-01-17T19:57:35.264412+00:00',
#   'doi': '10.5281/zenodo.5866422',
#   'files': [{'bucket': '7340f2db-e675-4f7f-8e67-67a54a97a5ca',
#     'checksum': 'md5:7b7f04a345c31e696b381e933dfc83c4',
#     'key': 'HPC_APOD_Guidelines.odt',
#     'links': {'self': 'https://zenodo.org/api/files/7340f2db-e675-4f7f-8e67-67a54a97a5ca/HPC_APOD_Guidelines.odt'},
#     'size': 19438,
#     'type': 'odt'},
#    {'bucket': '7340f2db-e675-4f7f-8e67-67a54a97a5ca',
#     'checksum': 'md5:a4b0de0dc996cd4e64eecf0441c5e084',
#     'key': 'HPC_APOD_Guidelines.pdf',
#     'links': {'self': 'https://zenodo.org/api/files/7340f2db-e675-4f7f-8e67-67a54a97a5ca/HPC_APOD_Guidelines.pdf'},
#     'size': 69915,
#     'type': 'pdf'}],
#   'id': 5866422,
#   'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5866422.svg',
#    'bucket': 'https://zenodo.org/api/files/7340f2db-e675-4f7f-8e67-67a54a97a5ca',
#    'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5866421.svg',
#    'conceptdoi': 'https://doi.org/10.5281/zenodo.5866421',
#    'doi': 'https://doi.org/10.5281/zenodo.5866422',
#    'html': 'https://zenodo.org/record/5866422',
#    'latest': 'https://zenodo.org/api/records/5866422',
#    'latest_html': 'https://zenodo.org/record/5866422',
#    'self': 'https://zenodo.org/api/records/5866422'},
#   'metadata': {'access_right': 'open',
#    'access_right_category': 'success',
#    'communities': [{'id': 'molssi'}, {'id': 'molssi-guidelines'}],
#    'creators': [{'affiliation': 'The Molecular Sciences Software Institute',
#      'name': 'Mostafanejad, Mohammad',
#      'orcid': '0000-0001-9762-7616'},
#     {'affiliation': 'The Molecular Sciences Software Institute',
#      'name': 'Saxe, Paul',
#      'orcid': '0000-0002-8641-9448'}],
#    'description': '<p>This document is based on <a href="https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html">NVIDIA&rsquo;s CUDA C++ Best Practices Guide</a> and overviews a systematic cyclic strategy for parallelizing serial codes using CUDA toolkit. The technical details on each stage of this process can be found in <a href="https://molssi.github.io/molssi-guidelines">MolSSI guidelines and best practices</a>&#39; collection in the high-performance computing section.</p>',
#    'doi': '10.5281/zenodo.5866422',
#    'keywords': ['CUDA programming',
#     'high-performance computing',
#     'GPUs',
#     'MolSSI guidelines',
#     'MolSSI best practices'],
#    'language': 'eng',
#    'license': {'id': 'CC-BY-4.0'},
#    'notes': 'This work has been funded by the NSF OAC-1547580 and CHE-2136142 grants.',
#    'publication_date': '2022-01-17',
#    'related_identifiers': [{'identifier': '10.5281/zenodo.5866421',
#      'relation': 'isVersionOf',
#      'scheme': 'doi'}],
#    'relations': {'version': [{'count': 1,
#       'index': 0,
#       'is_last': True,
#       'last_child': {'pid_type': 'recid', 'pid_value': '5866422'},
#       'parent': {'pid_type': 'recid', 'pid_value': '5866421'}}]},
#    'resource_type': {'subtype': 'technicalnote',
#     'title': 'Technical note',
#     'type': 'publication'},
#    'title': 'MolSSI Guidelines on APOD Cyclic Parallelization Strategy',
#    'version': '2022.1.17'},
#   'owners': [68559],
#   'revision': 2,
#   'stats': {'downloads': 12.0,
#    'unique_downloads': 10.0,
#    'unique_views': 17.0,
#    'version_downloads': 12.0,
#    'version_unique_downloads': 10.0,
#    'version_unique_views': 17.0,
#    'version_views': 20.0,
#    'version_volume': 788503.0,
#    'views': 20.0,
#    'volume': 788503.0},
#   'updated': '2022-01-18T01:48:53.159893+00:00'}]

# %%
res = reco.list_records(communities="molssi", size=2)
res
# pprint.pprint(res["aggregations"]["access_right"], indent=2)
# pprint.pprint(len(res["hits"]["hits"]), indent=2)
# reco.list_records(communities="molssi")
# Out:
# {'aggregations': {'access_right': {'buckets': [{'doc_count': 10,
#      'key': 'open'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0},
#   'file_type': {'buckets': [{'doc_count': 8, 'key': 'zip'},
#     {'doc_count': 2, 'key': 'odt'},
#     {'doc_count': 2, 'key': 'pdf'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0},
#   'keywords': {'buckets': [{'doc_count': 4, 'key': 'CCSD(T)'},
#     {'doc_count': 4, 'key': 'MP2'},
#     {'doc_count': 4, 'key': 'computational chemistry'},
#     {'doc_count': 4, 'key': 'computational materials science'},
#     {'doc_count': 4, 'key': 'coupled cluster'},
#     {'doc_count': 4, 'key': 'dimers'},
#     {'doc_count': 4, 'key': 'non-covalent interactions'},
#     {'doc_count': 2, 'key': 'MolSSI best practices'},
#     {'doc_count': 2, 'key': 'MolSSI guidelines'},
#     {'doc_count': 1, 'key': 'CUDA programming'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 7},
#   'type': {'buckets': [{'doc_count': 4,
#      'key': 'dataset',
#      'subtype': {'buckets': [],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 4,
#      'key': 'software',
#      'subtype': {'buckets': [],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 2,
#      'key': 'publication',
#      'subtype': {'buckets': [{'doc_count': 2, 'key': 'technicalnote'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0}},
#  'hits': {'hits': [], 'total': 10},
#  'links': {'prev': 'https://zenodo.org/api/records/?sort=bestmatch&all_versions=False&communities=molssi&page=19&size=2',
#   'self': 'https://zenodo.org/api/records/?sort=bestmatch&all_versions=False&communities=molssi&page=20&size=2'}}

# %%
rec1 = depo.create_deposition()
rec1._id

# %%
rec1 = depo.retrieve_deposition(id_=1095982)
rec1.data["links"]["bucket"]

# %%
# depo.delete_deposition(id_=rec1._id)
depo.delete_deposition(id_=1095982)

# %%
rec_rec = depo.update_deposition(
    id_=1095982,
    upload_type="publication",
    publication_type="book",
    creators=[{"name":"Mostafanejad, Sina"}],
    access_right="embargoed",
    embargo_date="2023-08-20",
    license="cc-by",
    title="My New Title",
    description="This is a new description"
    )
rec_rec.data

# %% [markdown]
# ### Update

# %%
url = "https://sandbox.zenodo.org/api/deposit/depositions"
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer T2U7Ip7TuQAdqjGzDNG10FsOiTJlkgAsbqXw1XxCypD2iN9hm2QrFD9uF9zJ"

}
# data = {
#     "metadata": {
#         "upload_type": "publication",
#         "publication_type": "book",
#         "access_right": "embargoed",
#         "embargo_date": "",
#         # "publication_date": datetime.now(timezone.utc).isoformat(),
#         "description": "This is a test metadata container",
#         "title": "This is the title I want to upload 2"
#     }
# }

data = {
    "metadata" : { 
    "upload_type":"publication",
    "publication_type":"book",
    "creators":[{"name":"Mostafanejad, Sina"}],
    "access_right":"embargoed",
    "embargo_date":"2023-08-20",
    "license":"cc-by",
    "title":"This is a new title",
    "description":"This is a new description"
    },
}
params = {
    "access_token": "T2U7Ip7TuQAdqjGzDNG10FsOiTJlkgAsbqXw1XxCypD2iN9hm2QrFD9uF9zJ"
}
r = requests.put(url=rec1.record_url, json=data, params=params)
r.json()

# %%
rec2 = depo.create_deposition()
rec2._id

# %%
from entities import metadata

# %%
met = {}
met["metadata"] = {}
met2 = met["metadata"]
met2["key"] = "value"
met2["key"] = "valval"
print(met)

# %%
if "sth" in metadata.upload_types.keys():
    print("True")
else:
    print("False")

# %%
import inspect
def func(a=0, b=1, c=2, **kwargs):
    for key, val in kwargs.items():
        print(key, val)
list(inspect.signature(func).parameters)

# %%
depo.delete_deposition(id_=rec._id)

# %%
rec = depo.retrieve_deposition(id_=5120243)

# %%
records = cli.init_records()

# %%
depo.delete_deposition(id_=6985343)

# %%
import requests

# %%
url = "https://zenodo.org/api/deposit/depositions"
headers = {"Content-Type": "application/json"}
query = {
    "query_string": {
        "query": "",
        "default_field": "content",
    }
}
params = {
    "q": query,
    'access_token': 'f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx'}
data = {"title": "DPC++"}
r = requests.get("https://zenodo.org/api/deposit/depositions/5120243", params=params, headers=headers)
r.links

# %%
rec = depo.retrieve_deposition(5120243)
rec.data

# %% [markdown]
# ### Work on the SANDBOX

# %%
params = {
    **query,
    'access_token': 'f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx',
}
print(params)

# %%
headers = {"Content-Type": "application/json"}
url="https://httpbin.org/delete"
r = requests.delete(url=url, headers=headers)
r.json()

# %%
url = 'http://127.0.0.1:5000/api/person'
headers = {'Content-Type': 'application/json'}

filters = [dict(name='id', op='==', val='1093084')]
params = dict(q=json.dumps(dict(filters=filters)))

response = requests.get(url, params=params, headers=headers)
assert response.status_code == 200
print(response.json())

# %%
x = "headers"
if x in [1, 0, False, True]:
    print("it's here")
else:
    print("not here")

# %%
datetime.now(timezone.utc).date().isoformat()

# %%
keys_list = ["communities", "type", "subtype", "bounds", "custom"]
keys_list2 = ["communities2", "type2", "subtype2", "bounds2", "custom2"]

for keys, vals in zip(keys_list, keys_list2):
    print(keys, vals)

# %%
url = "https://zenodo.org/api/licenses/cc-by-nc-4.0"
headers = {"Content-Type": "application/json"}
query = {
    "query_string": {
        "query": "",
        "default_field": "content",
    }
}
params = {
    "q": query,
    'access_token': 'f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx'}
data = {"title": "DPC++"}
r = requests.get(url=url)
r.json()
# Out:
# {'created': '2016-09-12T02:51:35.985727+00:00',
#  'id': 'cc-by-nc-4.0',
#  'links': {'self': 'https://zenodo.org/api/licenses/cc-by-nc-4.0'},
#  'metadata': {'$schema': 'http://zenodo.org/schemas/licenses/license-v1.0.0.json',
#   'domain_content': False,
#   'domain_data': False,
#   'domain_software': False,
#   'family': '',
#   'id': 'CC-BY-NC-4.0',
#   'maintainer': '',
#   'od_conformance': 'not reviewed',
#   'osd_conformance': 'not reviewed',
#   'status': 'active',
#   'title': 'Creative Commons Attribution Non Commercial 4.0 International',
#   'url': 'https://creativecommons.org/licenses/by-nc/4.0/legalcode'},
#  'updated': '2021-10-07T08:21:24.564024+00:00'}

# %%
url = "https://zenodo.org/api/funders"
headers = {"Content-Type": "application/json"}
query = {
    "query_string": {
        "query": "",
        "default_field": "content",
    }
}
params = {
    "q": query,
    'access_token': 'f4b2iI3HML9lnr3gUCyw12r3kWcDQS7WiGbZQEiv1L1m9RQFy5Ov4IuXwDWx'}
data = {"title": "DPC++"}
r = requests.get(url=url)
r.json()["hits"]["hits"][0]
# Out:
# {'created': '2018-08-14T15:22:59.987689+00:00',
#  'id': '10.13039/501100010363',
#  'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100010363'},
#  'metadata': {'$schema': 'http://zenodo.org/schemas/funders/funder-v1.0.0.json',
#   'acronyms': [],
#   'country': 'DK',
#   'doi': '10.13039/501100010363',
#   'identifiers': {'oaf': None},
#   'name': 'Minister Erna Hamiltons Legat for Videnskab og Kunst',
#   'parent': {},
#   'remote_created': '2018-03-22T11:31:31.000000',
#   'remote_modified': None,
#   'subtype': 'foundation',
#   'type': 'pri'},
#  'updated': '2018-08-14T15:22:59.987698+00:00'}
